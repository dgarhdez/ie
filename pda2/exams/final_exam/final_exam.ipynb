# %% [markdown]
# # Final Exam
#
# **Instructions:**
# - Complete all 13 exercises
# - Write clean, efficient code
# - Check and print your solutions to ensure they work correctly
# - You have to complete the exam
#
# **Rules:**
# * For each question, print the answer in the cell below the question. You can use `print()` or just type the variable name.
# * You can use any resources you like --including the internet, your notes, and the past notebooks-- except ChatGPT/Copilot/other AI writing tools. Using AI-based tools or asking other people for help will result in a 0 for the assignment, an immediate Fail in the course, and a report to the Dean of Students.
# * You have 80 minutes to complete the assignment.
# * You can submit the assignment as many times as you like, only the last submission will be graded.
# * You can't work with other people on the assignment.

# %% [markdown]
# ## Question 1: Advanced DateTime Feature Engineering
#
# Given a DataFrame with transaction dates, create the following features:
# 1. Day of year (1-366)
# 2. Week of year (1-52)
# 3. Quarter (1-4)
# 4. Is weekend (True/False)
# 5. Business day indicator (Monday-Friday = True)
#
# Calculate the average transaction amount for weekends vs weekdays and determine which has higher average transactions.

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
dates = pd.date_range("2024-01-01", periods=200, freq="D")
df = pd.DataFrame(
    {"transaction_date": dates, "amount": np.random.randint(50, 500, 200)}
)

# Your code here
# Out:
#     transaction_date  amount
# 0         2024-01-01     152
# 1         2024-01-02     485
# 2         2024-01-03     398
# 3         2024-01-04     320
# 4         2024-01-05     156
# ..               ...     ...
# 195       2024-07-14     490
# 196       2024-07-15     183
# 197       2024-07-16     333
# 198       2024-07-17      77
# 199       2024-07-18     157
#
# [200 rows x 2 columns]

# %% [markdown]
# ## Question 2: Complex Regex Data Extraction
#
# Given a Series of product descriptions, extract:
# 1. All product codes (format: ABC-1234 or XYZ-5678)
# 2. All prices (format: $XX.XX or $XXX.XX)
# 3. All dates (format: MM/DD/YYYY)
#
# Create a new DataFrame with columns: original_text, product_code, price, date.

# %%
products = pd.Series(
    [
        "Product ABC-1234 costs $129.99 and ships on 03/15/2024",
        "Item XYZ-5678 priced at $45.50 available 05/20/2024",
        "Special offer DEF-9012 for $299.00 ready by 07/01/2024",
        "Product GHI-3456 at $89.99 no date available",
        "New arrival JKL-7890 coming soon for $199.50",
    ]
)

# Your code here

# %% [markdown]
# ## Question 3: NumPy Statistical Analysis with Multiple Distributions
#
# Generate three datasets:
# - Dataset A: 50 samples from normal distribution (mean=100, std=15)
# - Dataset B: 50 samples from uniform distribution (50 to 150)
# - Dataset C: 50 samples from exponential distribution (scale=20)
#
# For each dataset, calculate:
# 1. Mean, median, and mode
# 2. 25th, 50th, 75th percentiles
# 3. Coefficient of variation (std/mean * 100)
#
# Determine which distribution has the highest coefficient of variation.

# %%
np.random.seed(42)

# Your code here

# %% [markdown]
# ## Question 4: Advanced Missing Value Strategy
#
# Create a DataFrame with 100 rows and 2 columns: date, temperature.
#
# Introduce random missing values with 15% missing in temperature
#
# Test 3 different strategies to handle missing values, and calculate the mean temperature after applying each strategy.

# %%
np.random.seed(42)

# Your code here

# %% [markdown]
# ## Question 5: Complex DateTime Shifting and Lagging
#
# Use the previous temperatures DataFrame, and after filling missing values, create the following features:
#
# 1. Previous 3 days average temperature
# 2. Next 2 days minimum temperature
# 3. Percentage change from previous day
#
# You can use any method to fill missing values before creating these features.

# %%
np.random.seed(42)

# Your code here

# %% [markdown]
# ## Question 6: Regex Pattern Matching and Extraction
#
# Given a DataFrame with user information:
# 1. Validate email addresses using a simple regex pattern (must have text, @, and domain)
# 2. Extract the domain name from valid emails (everything after @)
# 3. Identify if phone numbers match the format XXX-XXX-XXXX
# 4. Count how many valid emails and valid phone numbers exist in the dataset

# %%
df = pd.DataFrame(
    {
        "user_id": range(1, 11),
        "email": [
            "john.doe@company.com",
            "invalid.email@",
            "alice@subdomain.example.org",
            "bob@test",
            "charlie.brown@school.edu",
            "no-at-sign.com",
            "valid_user@domain.net",
            "another@domain.co.uk",
            "test@example",
            "final.user@service.io",
        ],
        "phone": [
            "123-456-7890",
            "(415) 555-0123",
            "555.123.4567",
            "invalid-phone",
            "987-654-3210",
            "(202) 555-9876",
            "800.555.1234",
            "not-a-number",
            "718-555-4567",
            "3105557890",
        ],
    }
)

# Your code here

# %% [markdown]
# ## Question 7: Unit Testing - Phone Number Validation Function
#
# Write a function called `validate_phone(phone_number)` that:
# - Takes a string representing a phone number
# - Returns True if the phone number matches the format XXX-XXX-XXXX (where X is a digit)
# - Returns False otherwise
#
# Write test functions `test_validate_phone_xxx()` using AAA pattern that test the following cases:
# 1. A valid phone number (e.g., "123-456-7890")
# 2. An invalid phone number with wrong format (e.g., "(123) 456-7890")
# 3. A completely invalid string (e.g., "not-a-phone")
# 4. A phone number with letters (e.g., "123-abc-7890")
#
# Run all tests and print "All tests passed!" if successful.

# %%
# Your code here
# 1. Write the validate_phone function
# 2. Write the test_validate_phone functions using AAA pattern
# 3. Run the test functions to verify correctness

# %% [markdown]
# ## Question 8: Feature Scaling with Outliers
#
# Given a DataFrame with 3 features containing some outliers:
# 1. Identify outliers using the IQR method (values below Q1 - 1.5*IQR or above Q3 + 1.5*IQR)
# 2. Count how many outliers exist in each column
# 3. Apply StandardScaler to scale all features
# 4. Print the mean and standard deviation of each scaled feature to verify scaling worked correctly

# %%
from sklearn.preprocessing import StandardScaler

np.random.seed(42)
df = pd.DataFrame(
    {
        "feature_A": np.concatenate(
            [np.random.normal(50, 10, 95), [150, 200, 180, 190, 175]]
        ),
        "feature_B": np.concatenate(
            [np.random.normal(100, 20, 95), [-50, 300, 280, -100, 320]]
        ),
        "feature_C": np.concatenate([np.random.normal(30, 5, 95), [5, 80, 90, 3, 85]]),
    }
)

# Your code here

# %% [markdown]
# ## Question 9: Rolling Window Calculations
#
# Given a time series of stock prices, calculate:
# 1. 7-day rolling mean
# 2. 7-day rolling standard deviation
# 3. 7-day rolling minimum and maximum
# 4. Identify days where the price is above 1.5 times the 7-day rolling mean
#
#
# Print the first 20 rows showing the original price and all calculated metrics.

# %%
np.random.seed(42)
dates = pd.date_range("2024-01-01", periods=100, freq="D")
prices = pd.Series(100 + np.cumsum(np.random.randn(100) * 2), index=dates)

# Your code here

# %% [markdown]
# ## Question 10: Categorical Encoding Strategies
#
# Given a DataFrame with a categorical column and a numeric value:
# 1. Perform label encoding on the categorical column
# 2. Perform one-hot encoding on the categorical column
# 3. Calculate the mean value for each category
# 4. Compare the shape of the original DataFrame vs the one-hot encoded version

# %%
np.random.seed(42)

df = pd.DataFrame(
    {
        "category": np.random.choice(["A", "B", "C", "D"], 100),
        "value": np.random.randint(10, 100, 100),
    }
)

# Your code here

# %% [markdown]
# ## Question 11: Unit Testing - Statistics Function
#
# Write a function called `calculate_summary_stats(numbers)` that:
# - Takes a list of numbers
# - Returns a dictionary with 'mean', 'median', 'min', 'max', and 'range' (max - min)
# - Raises ValueError if the list is empty
#
# Write test functions `test_calculate_summary_stats_xxx()` using AAA pattern that test:
#
# 1. A normal list of positive numbers
# 2. A list with negative numbers
#
# Run all tests and print "All tests passed!" if successful.

# %%
# Your code here
# 1. Write the validate_dataframe function
# 2. Write the test_validate_dataframe functions using AAA pattern
# 3. Run the test functions to verify correctness

# %% [markdown]
# ## Question 12: Unit Testing - Data Cleaning Function
#
# Write a function called `remove_outliers_iqr(data, column)` that:
# - Takes a DataFrame and a column name
# - Removes rows where the column value is an outlier (using IQR method: < Q1-1.5*IQR or > Q3+1.5*IQR)
# - Returns the cleaned DataFrame
#
# Write test functions `test_remove_outliers_iqr_xxx()` using AAA pattern that test:
# 1. A DataFrame with known outliers (verify they are removed)
# 2. A DataFrame with no outliers (verify length stays the same)
# 3. Verify that the function returns a DataFrame
#
# Run all tests and print results for each test case.

# %%
# Your code here
# 1. Write the calculate_returns function
# 2. Write the test_calculate_returns function using AAA pattern
# 3. Run the test function

# %% [markdown]
# ## Question 13: Data Transformation Pipeline
#
# Create a simple transformation pipeline that:
# 1. Fills missing values with the column mean
# 2. Scales numeric features to have values between 0 and 1 using Min-Max scaling
# 3. One-hot encodes the categorical columns
#
# Apply this pipeline to the given dataset and:
# - Print the shape before and after transformation
# - Show the first 5 rows of the transformed data
# - Verify that no missing values remain after transformation
#
# You can use ColumnTransformer and Pipeline from sklearn to build the pipeline.

# %%
np.random.seed(42)

df = pd.DataFrame(
    {
        "age": np.random.randint(20, 65, 100),
        "salary": np.random.randint(30000, 120000, 100),
        "experience": np.random.randint(0, 40, 100),
        "department": np.random.choice(["IT", "HR", "Sales", "Marketing"], 100),
    }
)

# Introduce some missing values
df.loc[np.random.choice(df.index, 10), "age"] = np.nan
df.loc[np.random.choice(df.index, 10), "salary"] = np.nan

# Your code here

# %% [markdown]
# ---
#
# ## End of Exam
#
# **Before submitting:**
# - Review all your answers
# - Ensure all code cells run without errors
# - Check that you've answered all parts of each question
# - Verify your output is clearly readable
#
# **Good luck!**
