# %% [markdown]
# # Practice Exercises

# %% [markdown]
# ## Exercise 1: Basic DateTime Operations
#
# Create a pandas Series with dates for the entire year 2024 (daily frequency) and extract the month name from each date.
#
# **Expected output**: A Series with month names like 'January', 'February', etc.

# %%
import pandas as pd
import numpy as np

# Your code here

# %% [markdown]
# ## Exercise 2: Simple Regex Pattern Matching
#
# Given a Series of email addresses, extract only the domain names (the part after @).
#
# Example: 'user@example.com' → 'example.com'

# %%
emails = pd.Series(
    ["john@gmail.com", "alice@yahoo.com", "bob@outlook.com", "eve@company.org"]
)

# Your code here

# %% [markdown]
# ## Exercise 3: NumPy Random Sampling
#
# Generate 1000 random samples from a normal distribution with mean=50 and standard deviation=10. Calculate the mean and standard deviation of your sample.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4: Handling Missing Values
#
# Create a DataFrame with random values and introduce 20% missing values randomly. Then fill the missing values with the column mean.

# %%
np.random.seed(42)
df = pd.DataFrame(np.random.randn(100, 3), columns=["A", "B", "C"])

# Your code here to introduce and handle missing values

# %% [markdown]
# ## Exercise 5: DateTime Shifting
#
# Create a DataFrame with a date column and a sales column. Add a new column that shows the previous day's sales (lag by 1 day).

# %%
dates = pd.date_range("2024-01-01", periods=30, freq="D")
sales = pd.Series(np.random.randint(100, 500, 30))

# Your code here

# %% [markdown]
# ## Exercise 6: Regex Extraction with Groups
#
# Given a Series of phone numbers in format '(XXX) XXX-XXXX', extract the area code (first three digits).

# %%
phones = pd.Series(
    ["(415) 555-0123", "(202) 555-9876", "(718) 555-4567", "(310) 555-7890"]
)

# Your code here

# %% [markdown]
# ## Exercise 7: NumPy Uniform Distribution
#
# Generate a 10x10 matrix of random numbers from a uniform distribution between 0 and 100. Find the indices of all values greater than 75.

# %%
# Your code here

# %% [markdown]
# ## Exercise 8: Simple Feature Scaling
#
# Create a DataFrame with random values and scale all columns to have values between 0 and 1 using Min-Max scaling (manual implementation).
#
# Formula: `scaled = (x - min) / (max - min)`

# %%
df = pd.DataFrame(
    {
        "feature1": [10, 20, 30, 40, 50],
        "feature2": [100, 200, 300, 400, 500],
        "feature3": [1, 2, 3, 4, 5],
    }
)

# Your code here

# %% [markdown]
# ## Exercise 9: Rolling Window Calculations
#
# Create a time series of daily temperatures and calculate a 7-day moving average. Compare the original and smoothed series.

# %%
dates = pd.date_range("2024-01-01", periods=90, freq="D")
temps = pd.Series(np.random.randint(15, 30, 90), index=dates)

# Your code here

# %% [markdown]
# ## Exercise 10: Categorical Encoding
#
# Create a DataFrame with a categorical column (e.g., 'red', 'green', 'blue') and perform both label encoding and one-hot encoding on it.

# %%
df = pd.DataFrame(
    {
        "color": ["red", "blue", "green", "red", "blue", "green", "red"],
        "value": [10, 20, 15, 12, 18, 22, 11],
    }
)

# Your code here

# %% [markdown]
# ## Exercise 11: Complex Regex Validation
#
# Given a Series of strings, identify which ones are valid email addresses using regex. A valid email has:
# - Alphanumeric characters, dots, underscores, or hyphens before @
# - A domain with at least one dot
# - 2-4 letters after the final dot

# %%
strings = pd.Series(
    [
        "valid.email@example.com",
        "invalid@email",
        "also.valid@sub.domain.org",
        "not-an-email",
        "test_123@company.co.uk",
    ]
)

# Your code here

# %% [markdown]
# ## Exercise 12: DateTime Rolling with Multiple Operations
#
# Create a stock price DataFrame with daily data. Calculate:
# 1. 7-day rolling mean
# 2. 7-day rolling standard deviation
# 3. 7-day rolling minimum and maximum
#
# Then identify days where the price is more than 1 standard deviation above the rolling mean.

# %%
dates = pd.date_range("2024-01-01", periods=100, freq="D")
prices = pd.Series(100 + np.cumsum(np.random.randn(100)), index=dates)

# Your code here

# %% [markdown]
# ## Exercise 13: Advanced NaN Handling
#
# Create a DataFrame with different types of missing data patterns. Implement:
# 1. Forward fill for time-series columns
# 2. Backward fill for categorical columns
# 3. Mean imputation for numeric columns
# 4. Create an indicator column showing which rows had missing values

# %%
np.random.seed(42)
df = pd.DataFrame(
    {
        "date": pd.date_range("2024-01-01", periods=20),
        "temperature": np.random.randint(15, 30, 20),
        "category": np.random.choice(["A", "B", "C"], 20),
        "value": np.random.randn(20),
    }
)

# Introduce missing values
df.loc[3:5, "temperature"] = np.nan
df.loc[8:10, "category"] = np.nan
df.loc[15:17, "value"] = np.nan

# Your code here

# %% [markdown]
# ## Exercise 14: StandardScaler from Sklearn
#
# Use sklearn's StandardScaler to standardize a dataset. Then manually verify the result by checking that the mean is ~0 and std is ~1.

# %%
from sklearn.preprocessing import StandardScaler

df = pd.DataFrame(
    {
        "height": [150, 160, 170, 180, 190],
        "weight": [50, 60, 70, 80, 90],
        "age": [20, 25, 30, 35, 40],
    }
)

# Your code here

# %% [markdown]
# ## Exercise 15: Unit Testing - Calculate Statistics Function
#
# Write a function called `calculate_statistics(numbers)` that takes a list of numbers and returns a dictionary with:
# - 'mean': the average
# - 'median': the median value
# - 'std': the standard deviation
#
# Then write a test function called `test_calculate_statistics()` following the AAA pattern (Arrange, Act, Assert) without using pytest. The test should verify that the function works correctly with a known input. Run the test function in the same cell.
#
# **Note**: Use assertions to verify correctness. If all tests pass, print "All tests passed!"

# %%
# Your code here
# 1. Write the calculate_statistics function
# 2. Write the test_calculate_statistics function using AAA pattern
# 3. Run the test function

# %% [markdown]
# ## Exercise 16: Unit Testing - DataFrame Filtering Function
#
# Write a function called `filter_outliers(df, column, n_std=2)` that:
# - Takes a pandas DataFrame, a column name, and number of standard deviations
# - Returns a new DataFrame with rows removed where the column value is more than `n_std` standard deviations from the mean
#
# Then write a test function called `test_filter_outliers()` using the AAA pattern (Arrange, Act, Assert) without using pytest. The test should:
# 1. Create a test DataFrame with known outliers
# 2. Call the function
# 3. Assert that the outliers are removed and normal values remain
#
# Run the test function in the same cell and print "All tests passed!" if successful.

# %%
# Your code here
# 1. Write the filter_outliers function
# 2. Write the test_filter_outliers function using AAA pattern
# 3. Run the test function

# %% [markdown]
# ## Exercise 17: Advanced Rolling Windows with Custom Functions
#
# Create a time series and calculate:
# 1. A 7-day rolling median
# 2. A 7-day rolling quantile (75th percentile)
# 3. A custom rolling function that calculates the range (max - min)
# 4. An expanding window mean (cumulative average)

# %%
dates = pd.date_range("2024-01-01", periods=60, freq="D")
values = pd.Series(np.random.randint(10, 100, 60), index=dates)

# Your code here

# %% [markdown]
# ## Exercise 18: Building a Simple Pipeline
#
# Create a sklearn pipeline that:
# 1. Imputes missing values with the median
# 2. Scales features using StandardScaler
# 3. Applies PCA to reduce dimensions to 2 components
#
# Apply this pipeline to a dataset with missing values.

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Create sample data with missing values
np.random.seed(42)
X = pd.DataFrame(np.random.randn(100, 5), columns=[f"feature_{i}" for i in range(5)])
X.loc[np.random.choice(X.index, 10), "feature_0"] = np.nan
X.loc[np.random.choice(X.index, 10), "feature_2"] = np.nan

# Your code here

# %% [markdown]
# ## Exercise 19: ColumnTransformer for Mixed Data Types
#
# Create a dataset with both numerical and categorical features. Use ColumnTransformer to:
# 1. Apply StandardScaler to numerical columns
# 2. Apply OneHotEncoder to categorical columns
# 3. Combine the results into a single array
#
# Dataset includes: age (numeric), salary (numeric), department (categorical), city (categorical)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

df = pd.DataFrame(
    {
        "age": [25, 30, 35, 40, 45, 50, 28, 33],
        "salary": [50000, 60000, 70000, 80000, 90000, 100000, 55000, 65000],
        "department": ["IT", "HR", "IT", "Sales", "HR", "IT", "Sales", "HR"],
        "city": ["NYC", "LA", "Chicago", "NYC", "LA", "Chicago", "NYC", "LA"],
    }
)

# Your code here

# %% [markdown]
# ## Exercise 20: Complete ML Pipeline with All Components
#
# Create a comprehensive pipeline that handles a realistic dataset with:
# - Numerical features (with missing values)
# - Categorical features (with missing values)
# - Date features (extract year, month, day of week)
# - Text features (extract length, word count)
#
# Your pipeline should:
# 1. Handle missing values appropriately for each type
# 2. Extract features from dates
# 3. Encode categorical variables
# 4. Scale numerical features
# 5. Create polynomial features for specific numerical columns
#
# Apply this to predict a target variable using a simple model (e.g., LinearRegression).

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PolynomialFeatures
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Create a realistic dataset
np.random.seed(42)
n_samples = 200

df = pd.DataFrame(
    {
        "date": pd.date_range("2024-01-01", periods=n_samples, freq="D"),
        "age": np.random.randint(20, 65, n_samples),
        "income": np.random.randint(30000, 120000, n_samples),
        "experience_years": np.random.randint(0, 40, n_samples),
        "department": np.random.choice(["IT", "HR", "Sales", "Marketing"], n_samples),
        "education": np.random.choice(["Bachelor", "Master", "PhD"], n_samples),
        "description": [
            "Sample text " * np.random.randint(5, 20) for _ in range(n_samples)
        ],
        "target": np.random.randn(n_samples) * 10 + 50,
    }
)

# Introduce missing values
df.loc[np.random.choice(df.index, 20), "age"] = np.nan
df.loc[np.random.choice(df.index, 15), "income"] = np.nan
df.loc[np.random.choice(df.index, 10), "department"] = np.nan

# Your code here
# Build a complete pipeline and train a model
