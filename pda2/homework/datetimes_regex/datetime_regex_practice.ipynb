# %% [markdown]
# ## Part 0: Setup and Initial Exploration
#
# **Time:** 5 minutes

# %%
# Import required libraries
import pandas as pd
import numpy as np
import re
from datetime import datetime, timedelta

# Display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option("display.width", None)

# %%
# Load the data
df = pd.read_csv("ecommerce_transactions.csv")

# Display basic information
print(f"Dataset shape: {df.shape}")
print(f"\nColumns: {list(df.columns)}")

# %%
# Display first few rows

# %%
# Display dataset info

# %%
# Check for missing values

# %% [markdown]
# ---
#
# ## Part 1: Datetime Parsing and Conversion
#
# **Time:** 20 minutes
#
# The `transaction_timestamp` column contains dates in multiple formats. We need to parse them into a standardized datetime format.

# %% [markdown]
# ### Exercise 1.1: Examine timestamp formats
#
# Display a sample of different timestamp formats in the data.

# %%
# Display sample timestamps to see the different formats

# %% [markdown]
# ### Exercise 1.2: Parse mixed date formats
#
# Convert the `transaction_timestamp` column to datetime, handling multiple formats. Use `pd.to_datetime()` with appropriate parameters.

# %%
# Parse timestamps to datetime
# Hint: Use errors='coerce' to handle unparseable dates

# %% [markdown]
# ### Exercise 1.3: Identify parsing issues
#
# Find how many timestamps failed to parse (became NaT - Not a Time).

# %%
# Count NaT values after parsing

# %% [markdown]
# ### Exercise 1.4: Extract datetime components
#
# Create new columns with the following datetime components:
# - `year`
# - `month`
# - `day`
# - `hour`
# - `day_of_week` (0=Monday, 6=Sunday)
# - `quarter`
# - `is_weekend` (boolean)

# %%
# Extract datetime components

# %% [markdown]
# ### Exercise 1.5: Create hour category
#
# Create a `time_of_day` column with categories:
# - 'morning' (6-11)
# - 'afternoon' (12-17)
# - 'evening' (18-22)
# - 'night' (23-5)

# %%
# Create time of day categories

# %% [markdown]
# ### Exercise 1.6: Identify and handle date outliers
#
# Find transactions with:
# - Dates before 2024-01-01
# - Dates after 2026-01-29 (future dates)
#
# Display these outliers and consider how to handle them.

# %%
# Find date outliers

# %%
# Optional: Replace outlier dates with median date or mark as invalid

# %% [markdown]
# ---
#
# ## Part 2: String Cleaning and Standardization
#
# **Time:** 20 minutes
#
# Clean and standardize text columns to ensure consistency.

# %% [markdown]
# ### Exercise 2.1: Clean customer names
#
# 1. Remove leading/trailing whitespace
# 2. Convert to title case (capitalize first letter of each word)
# 3. Store cleaned names in a new column `customer_name_clean`

# %%
# Clean customer names

# %% [markdown]
# ### Exercise 2.2: Standardize email addresses
#
# 1. Convert all emails to lowercase
# 2. Remove any whitespace
# 3. Store in `customer_email_clean`

# %%
# Standardize emails

# %% [markdown]
# ### Exercise 2.3: Clean amount field
#
# Convert the `amount` column to float:
# 1. Remove currency symbols ($, €, £)
# 2. Remove commas
# 3. Convert to float
# 4. Store in `amount_numeric`

# %%
# Clean and convert amount

# %% [markdown]
# ### Exercise 2.4: Standardize payment methods
#
# Create a `payment_category` column that groups payment methods into:
# - 'credit_card'
# - 'debit_card'
# - 'digital_wallet' (PayPal, Apple Pay, Google Pay)
# - 'other'
#
# Hint: Use `.str.lower()` and `.str.contains()` to identify patterns.

# %%
# Categorize payment methods

# %% [markdown]
# ---
#
# ## Part 3: Regular Expression Pattern Matching
#
# **Time:** 25 minutes
#
# Use regex to extract structured information from text fields.

# %% [markdown]
# ### Exercise 3.1: Extract date from transaction_id
#
# The `transaction_id` has format: `TXN-YYYYMMDD-XXXXXX`
#
# Extract the date portion (YYYYMMDD) into a new column `txn_date_from_id`.
#
# Hint: Use `.str.extract()` with a regex pattern containing groups `()`.

# %%
# Extract date from transaction ID
# Pattern: TXN-YYYYMMDD-XXXXXX

# %% [markdown]
# ### Exercise 3.2: Parse customer region from customer_id
#
# The `customer_id` has format: `CUST-{REGION}-{NUMBER}`
#
# Extract the region code into a new column `customer_region`.
#
# Example: `CUST-US-0001` → `US`

# %%
# Extract customer region

# %% [markdown]
# ### Exercise 3.3: Extract product category hierarchy
#
# The `product_code` has format: `{CATEGORY}-{SUBCATEGORY}-{ID}`
#
# Extract:
# - `product_category` (e.g., ELEC, CLOTH, HOME)
# - `product_subcategory` (e.g., PHONE, SHIRT, FURNITURE)
#
# Example: `ELEC-PHONE-1234` → category: `ELEC`, subcategory: `PHONE`

# %%
# Extract product category

# %%
# Extract product subcategory

# %% [markdown]
# ### Exercise 3.4: Validate email addresses
#
# Create a boolean column `is_valid_email` that checks if the email matches a basic email pattern:
# - One or more word characters
# - Followed by `@`
# - Followed by domain name
# - Followed by `.` and extension
#
# Basic pattern: `\w+@\w+\.\w+`

# %%
# Validate email format

# %%
# Count valid vs invalid emails

# %% [markdown]
# ### Exercise 3.5: Extract email domain
#
# Extract the domain (e.g., `example.com`) from valid email addresses into a new column `email_domain`.
#
# Hint: Extract everything after the `@` symbol.

# %%
# Extract email domain

# %% [markdown]
# ### Exercise 3.6: Extract ZIP/postal codes from addresses
#
# Extract postal codes from `shipping_address`:
# - US ZIP codes: 5 digits (e.g., 10001)
# - UK postcodes: pattern like SW1A 1AA
#
# Create a `postal_code` column.
#
# Hint: Use `\d{5}` for US ZIP codes and a more complex pattern for UK postcodes, or use `str.extract()` with `|` (OR) operator.

# %%
# Extract postal codes
# Pattern for US ZIP: \d{5}
# Pattern for UK postcode: [A-Z]{1,2}\d{1,2}[A-Z]?\s?\d[A-Z]{2}

# %% [markdown]
# ### Exercise 3.7: Extract order status
#
# The `order_status` column contains status text and sometimes embedded dates.
#
# Extract the main status (Delivered, Shipped, Processing, Cancelled) into a new column `status_clean`.

# %%
# Extract main status

# %% [markdown]
# ---
#
# ## Part 4: Time Series Indexing and Filtering
#
# **Time:** 20 minutes
#
# Work with datetime index for efficient time-based filtering.

# %% [markdown]
# ### Exercise 4.1: Set datetime index
#
# Create a new DataFrame `df_ts` with:
# 1. `transaction_datetime` as the index
# 2. Sorted by datetime

# %%
# Create time series DataFrame with datetime index

# %% [markdown]
# ### Exercise 4.2: Filter by date ranges
#
# Extract the following subsets:
#
# 1. All transactions in 2024
# 2. Transactions in Q4 2024 (October-December)
# 3. Transactions in December 2024

# %%
# All transactions in 2024

# %%
# Q4 2024 transactions

# %%
# December 2024 transactions

# %% [markdown]
# ### Exercise 4.3: Filter by time of day
#
# Find:
# 1. Business hours transactions (9 AM - 5 PM)
# 2. Evening transactions (after 6 PM)
# 3. Weekend transactions

# %%
# Business hours (9 AM - 5 PM)

# %%
# Evening transactions (after 6 PM)

# %%
# Weekend transactions

# %% [markdown]
# ### Exercise 4.4: Complex filtering
#
# Find:
# 1. Electronics (ELEC) purchases in December 2024
# 2. Weekend transactions over $100
# 3. Weekday morning transactions (6-11 AM, Mon-Fri) in Q1 2024

# %%
# Electronics in December 2024

# %%
# Weekend transactions over $100

# %%
# Weekday mornings in Q1 2024

# %% [markdown]
# ---
#
# ## Part 5: Time Series Aggregation and Resampling
#
# **Time:** 25 minutes
#
# Aggregate transaction data at different time frequencies.

# %% [markdown]
# ### Exercise 5.1: Daily aggregations
#
# Calculate for each day:
# 1. Number of transactions
# 2. Total revenue
# 3. Average transaction amount

# %%
# Daily transaction count

# %%
# Daily total revenue

# %%
# Daily average transaction amount

# %% [markdown]
# ### Exercise 5.2: Resample to different frequencies
#
# Using `.resample()`, calculate total revenue at different frequencies:
# 1. Weekly ('W')
# 2. Monthly ('M')
# 3. Quarterly ('Q')

# %%
# Weekly revenue

# %%
# Monthly revenue

# %%
# Quarterly revenue

# %% [markdown]
# ### Exercise 5.3: Category-specific aggregations
#
# Calculate:
# 1. Monthly revenue by product category
# 2. Weekly transaction count by payment category
# 3. Monthly average transaction by customer region

# %%
# Monthly revenue by product category

# %%
# Weekly transactions by payment category

# %%
# Monthly average by region

# %% [markdown]
# ### Exercise 5.4: Time-based metrics
#
# Find:
# 1. Peak transaction hour (which hour has most transactions)
# 2. Busiest day of week
# 3. Month-over-month revenue growth rate

# %%
# Peak hour

# %%
# Busiest day of week

# %%
# Month-over-month growth

# %% [markdown]
# ---
#
# ## Part 6: Rolling Windows and Time Shifts
#
# **Time:** 20 minutes
#
# Calculate moving averages and period-over-period comparisons.

# %% [markdown]
# ### Exercise 6.1: Calculate rolling averages
#
# Create a daily revenue series and calculate:
# 1. 7-day rolling average
# 2. 30-day rolling average
# 3. 7-day rolling standard deviation

# %%
# Daily revenue series

# %%
# 7-day rolling average

# %%
# 30-day rolling average

# %%
# 7-day rolling standard deviation

# %% [markdown]
# ### Exercise 6.2: Lag and lead operations
#
# Using the daily revenue series:
# 1. Get previous day's revenue (lag 1)
# 2. Get revenue from 7 days ago (lag 7)
# 3. Calculate day-over-day change

# %%
# Previous day revenue

# %%
# Revenue from 7 days ago

# %%
# Day-over-day change

# %% [markdown]
# ### Exercise 6.3: Period-over-period calculations
#
# Calculate:
# 1. Week-over-week percentage change in revenue
# 2. Month-over-month percentage change in transaction count

# %%
# Week-over-week percentage change

# %%
# Month-over-month percentage change

# %% [markdown]
# ### Exercise 6.4: Trend analysis
#
# 1. Compare daily revenue to its 7-day moving average
# 2. Create a boolean column indicating if daily revenue is above the 7-day average
# 3. Count how many days are above vs below trend

# %%
# Compare daily to 7-day average

# %%
# Days above vs below trend

# %% [markdown]
# ---
#
# ## Part 7: Integrated Analysis
#
# **Time:** 25 minutes
#
# Combine all techniques to extract business insights.

# %% [markdown]
# ### Exercise 7.1: Regional performance analysis
#
# Analyze performance by customer region:
# 1. Total revenue by region
# 2. Average transaction amount by region
# 3. Monthly revenue trend by region (pivot table)

# %%
# Revenue by region

# %%
# Average transaction by region

# %%
# Monthly revenue by region (pivot table)

# %% [markdown]
# ### Exercise 7.2: Product category performance
#
# 1. Identify top 3 product categories by revenue
# 2. Calculate monthly revenue trend for each category
# 3. Find which category had the highest growth rate from 2024 to 2025

# %%
# Top 3 categories by revenue

# %%
# Monthly revenue by category

# %%
# Category with highest growth

# %% [markdown]
# ### Exercise 7.3: Email marketing analysis
#
# 1. Count customers with valid vs invalid emails
# 2. Find top 5 email domains by customer count
# 3. Compare average transaction amount for customers with valid vs invalid emails

# %%
# Valid vs invalid emails

# %%
# Top 5 email domains

# %%
# Compare transaction amounts

# %% [markdown]
# ### Exercise 7.4: Comprehensive business dashboard
#
# Create a summary report showing:
# 1. Total transactions and revenue (all time)
# 2. Best performing month (by revenue)
# 3. Best performing day of week
# 4. Peak shopping hour
# 5. Top product category
# 6. Top customer region
# 7. Most popular payment method
# 8. Average order value

# %%
# Create business dashboard summary
print("=" * 60)
print("E-COMMERCE BUSINESS DASHBOARD")
print("=" * 60)
print()

# Your code here to calculate and display metrics

# %% [markdown]
# ### Exercise 7.5: Seasonal trends analysis
#
# 1. Create a pivot table showing revenue by product category and quarter
# 2. Identify which categories show seasonal patterns (Q4 spike)
# 3. Calculate what percentage of annual revenue comes from Q4

# %%
# Revenue by category and quarter

# %%
# Q4 as percentage of annual revenue

# %% [markdown]
# ---
#
# ## Conclusion
#
# Congratulations! You've completed a comprehensive practice on:
#
# ✅ Parsing and handling mixed datetime formats
# ✅ Extracting datetime components
# ✅ Cleaning and standardizing text data
# ✅ Using regular expressions for pattern matching
# ✅ Filtering and indexing time series
# ✅ Aggregating and resampling data
# ✅ Calculating rolling windows and time shifts
# ✅ Combining techniques for real-world analysis
#
# ## Key Takeaways
#
# 1. **Real data is messy** - Always explore and validate your data
# 2. **Regex is powerful** - Learn common patterns for text extraction
# 3. **Datetime operations are essential** - Master the `.dt` accessor and resampling
# 4. **Chain operations efficiently** - Combine multiple pandas methods
# 5. **Think about business context** - Technical skills serve business goals
#
# ## Next Steps
#
# - Practice with your own datasets
# - Explore data visualization (matplotlib, seaborn, plotly)
# - Learn more advanced regex patterns
# - Study time series forecasting
# - Build automated data cleaning pipelines
