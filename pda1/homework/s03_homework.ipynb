# %% [markdown]
# # Session 03 - Homework

# %% [markdown]
# ### Exercise 1
#
# Create a string that introduces yourself. The string should include your name, age, and favorite color.
#
# Use string formatting to include the values of the variables in the string.

# %% [markdown]
# ### Exercise 2
#
# Create a string that includes all the letters in the alphabet with even indexes.

# %% [markdown]
# ### Interlude: the `input()` function
#
# The `input()` function is a built-in function in Python that allows us to get input from the user. The `input()` function takes a string as an argument, which is the prompt that will be displayed to the user.
#
# We can save the input in a variable, and use that information in our program.

# %%
name = input("What is your name? ")

print(f"Your name is {name}")
# Out:
# Your name is Dani

# %% [markdown]
# ### Exercise 3
#
# Using the `input()` function, ask the user for their name, age, and favorite color.
#
# Create a string that introduces the user, using the values entered by the user.

# %% [markdown]
# ### Exercise 4
#
# How can I check if a string and its reverse, are included in a palindrome?
#
# Use this palindrome: `Go hang a salami, I’m a lasagna hog`, and look for the word `salami` and its reverse.

# %% [markdown]
# ### Exercise 5
#
# Count how many times the letter `a` appears in the following string
#
# "A man a plan a canal Panama"

# %% [markdown]
# ### Exercise 6
#
# Create a string that contains the first 10 digits of pi (3.1415926535).

# %% [markdown]
# ### Exercise 7
#
# Given this string, extract the following substrings:
#
# "The quick brown fox jumps over the lazy dog"
#
# You can apply slicing multiple times.
#
# 1. "quick brown"
# 2. "god"
# 3. "qikbon"
# 4. "spmuj revo eht"

# %% [markdown]
# ### Exercise 8
#
# Create a variable with your full name (first name and last name separated by a space).
#
# Using string methods, create three new variables:
# 1. One with your full name in uppercase
# 2. One with your full name in lowercase
# 3. One with your full name in title case (first letter of each word capitalized)

# %% [markdown]
# ### Exercise 9
#
# Create a string with the following text: "   Python is amazing!   " (with spaces at the beginning and end).
#
# Use string methods to:
# 1. Remove all leading and trailing spaces
# 2. Remove only the leading spaces
# 3. Remove only the trailing spaces

# %% [markdown]
# ### Exercise 10
#
# Create a string with the following email address: "student@university.edu"
#
# Using string methods, extract:
# 1. The username (the part before the @)
# 2. The domain (the part after the @)
# 3. Check if the email ends with ".edu"

# %% [markdown]
# ### Exercise 11
#
# Create a string with this sentence: "I love programming in Python"
#
# Replace the word "love" with "enjoy" and then replace "Python" with "JavaScript".

# %% [markdown]
# ### Exercise 12
#
# Create a variable with the following text: "Hello-World-From-Python"
#
# Using string methods:
# 1. Replace all the hyphens (-) with spaces
# 2. Count how many hyphens are in the original string

# %% [markdown]
# ### Exercise 13
#
# Create a string with your favorite book or movie title.
#
# Using string methods, find:
# 1. The position (index) of the first space in the title
# 2. The length of the title
# 3. Whether the title starts with "The"

# %% [markdown]
# ### Exercise 14
#
# Create a string with the alphabet: "abcdefghijklmnopqrstuvwxyz"
#
# Using string indexing and slicing:
# 1. Get the first 5 letters
# 2. Get the last 5 letters
# 3. Get every third letter from the alphabet

# %% [markdown]
# ### Exercise 15
#
# Create two string variables:
# - first_word = "Data"
# - second_word = "Science"
#
# Concatenate these two words with a space in between to create "Data Science".
#
# Then, create another variable that repeats "Data Science" 3 times with a comma and space between each repetition.

# %% [markdown]
# ### Exercise 16
#
# Create a variable with this URL: "https://www.example.com/blog/python-tutorial"
#
# Using string methods:
# 1. Check if the URL starts with "https://"
# 2. Check if the URL contains the word "python"
# 3. Extract just the domain name (www.example.com)

# %% [markdown]
# ### Exercise 17
#
# Create a string with this sentence: "Python, Java, JavaScript, Ruby, Go"
#
# Using string methods:
# 1. Split the sentence into individual programming languages (hint: use the split method)
# 2. Count how many programming languages are in the list
# 3. Check if "C++" is in the list

# %% [markdown]
# ### Exercise 18
#
# Create a string variable with this phone number: "123-456-7890"
#
# Using string methods:
# 1. Remove all the hyphens to get just the digits
# 2. Check if the resulting string contains only numeric characters (hint: use the isdigit method)
# 3. Find the length of the phone number (with hyphens)

# %% [markdown]
# ### Exercise 19
#
# Create a string with this sentence: "the quick BROWN fox JUMPS over THE lazy DOG"
#
# Using string methods:
# 1. Convert the entire sentence to lowercase
# 2. Convert the entire sentence to uppercase
# 3. Use the swapcase method to swap the case of all letters (lowercase becomes uppercase and vice versa)

# %% [markdown]
# ### Exercise 20
#
# Create a string with your birth year (for example: "1995")
#
# 1. Check if the string contains only digits
# 2. Repeat the year 5 times with a hyphen (-) between each occurrence
# 3. Calculate your approximate age by subtracting your birth year from 2025 (hint: you'll need to convert the string to an integer using int())
