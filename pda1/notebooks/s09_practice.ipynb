# %% [markdown]
# # Session 09: Practice
#
# We are going to use the following dataset to practice the concepts learned about conditionals and loops.

# %%
students = [
    {
    "Surname 1": "Alessandri",
    "Surname 2": "Cruzat",
    "Name": "Teresita",
    "Email": "talessandri@student.ie.edu",
    "Nationality": "Chile"
    },
    {
    "Surname 1": "Aljneibi",
    "Surname 2": "",
    "Name": "Mohamed",
    "Email": "maljneibi@student.ie.edu",
    "Nationality": "UAE"
    },
    {
    "Surname 1": "Benavides Campos",
    "Surname 2": "",
    "Name": "Ivette Monserrat",
    "Email": "ivette.benavides@student.ie.edu",
    "Nationality": "Mexico"
    },
    {
    "Surname 1": "Bourbon",
    "Surname 2": "",
    "Name": "Maria",
    "Email": "mariabourbon@student.ie.edu",
    "Nationality": "Portugal"
    },
    {
    "Surname 1": "Caceres",
    "Surname 2": "Cavero",
    "Name": "Paula",
    "Email": "pcacerescavero@student.ie.edu",
    "Nationality": "Spain"
    },
    {
    "Surname 1": "Calderon",
    "Surname 2": "Reyes",
    "Name": "Erick Gerardo",
    "Email": "e.calderonr7@student.ie.edu",
    "Nationality": "Chile"
    },
    {
    "Surname 1": "Chhabra",
    "Surname 2": "",
    "Name": "Shambhavi",
    "Email": "shambhavichhabra@student.ie.edu",
    "Nationality": "India"
    },
    {
    "Surname 1": "Cuéllar",
    "Surname 2": "Michelsen",
    "Name": "Jaime",
    "Email": "jaime.cuellar@student.ie.edu",
    "Nationality": "Spain"
    },
    {
    "Surname 1": "El-Haddad",
    "Surname 2": "",
    "Name": "Christelle",
    "Email": "christelle.elhaddad@student.ie.edu",
    "Nationality": "Canada"
    },
    {
    "Surname 1": "Faena",
    "Surname 2": "",
    "Name": "Rocio",
    "Email": "rfaena@student.ie.edu",
    "Nationality": "Argentina"
    },
    {
    "Surname 1": "Fenaer",
    "Surname 2": "",
    "Name": "Radwan Mohamed S",
    "Email": "r.fenear@student.ie.edu",
    "Nationality": "Libya"
    },
    {
    "Surname 1": "Feng",
    "Surname 2": "",
    "Name": "Linran",
    "Email": "yvo.feng@student.ie.edu",
    "Nationality": "China"
    },
    {
    "Surname 1": "Francisco",
    "Surname 2": "",
    "Name": "Crissa Nicole",
    "Email": "crissa.francisco@student.ie.edu",
    "Nationality": "Philippines"
    },
    {
    "Surname 1": "Gonzalez",
    "Surname 2": "",
    "Name": "Laura Valentina",
    "Email": "laura.valentina@student.ie.edu",
    "Nationality": "Colombia"
    },
    {
    "Surname 1": "He Chen",
    "Surname 2": "",
    "Name": "Kenny Jiaxi",
    "Email": "kennyhe@student.ie.edu",
    "Nationality": "Peru"
    },
    {
    "Surname 1": "Hernández",
    "Surname 2": "Montes",
    "Name": "María Fernanda",
    "Email": "fernanda.hernandez@student.ie.edu",
    "Nationality": "Mexican"
    },
    {
    "Surname 1": "Herrera",
    "Surname 2": "Fidanque",
    "Name": "Emma Lucille",
    "Email": "emmalucille2001@student.ie.edu",
    "Nationality": "Panama"
    },
    {
    "Surname 1": "Izewski",
    "Surname 2": "",
    "Name": "Jakub",
    "Email": "jakub.izewski@student.ie.edu",
    "Nationality": "Poland"
    },
    {
    "Surname 1": "Kadena",
    "Surname 2": "Matsuda",
    "Name": "Matias",
    "Email": "matiaskama@student.ie.edu",
    "Nationality": "Peru"
    },
    {
    "Surname 1": "Kebede",
    "Surname 2": "",
    "Name": "Hildana",
    "Email": "hildana.kebede@student.ie.edu",
    "Nationality": "Ethiopia"
    },
    {
    "Surname 1": "Khanderia",
    "Surname 2": "",
    "Name": "Aryan",
    "Email": "aryankhanderia@student.ie.edu",
    "Nationality": "India"
    },
    {
    "Surname 1": "Latre",
    "Surname 2": "Porta",
    "Name": "Pilar",
    "Email": "pilar.latre@student.ie.edu",
    "Nationality": "Spain"
    },
    {
    "Surname 1": "Llort",
    "Surname 2": "Tejeda",
    "Name": "Isaura",
    "Email": "isaurallort@student.ie.edu",
    "Nationality": "Spain"
    },
    {
    "Surname 1": "Lopes Vale Estrada de Barros",
    "Surname 2": "",
    "Name": "Laura",
    "Email": "lauravlbarros@student.ie.edu",
    "Nationality": "Portugal"
    },
    {
    "Surname 1": "Mohaisen",
    "Surname 2": "",
    "Name": "Louay",
    "Email": "louaymohaisen@student.ie.edu",
    "Nationality": "Syria"
    },
    {
    "Surname 1": "Moreno Gonzalez",
    "Surname 2": "",
    "Name": "Oscar Ricardo Genaro",
    "Email": "ricardomg91@student.ie.edu",
    "Nationality": "Mexico"
    },
    {
    "Surname 1": "Morfín",
    "Surname 2": "Guerrero",
    "Name": "Jose Antonio",
    "Email": "antoniomorfin@student.ie.edu",
    "Nationality": "Mexico"
    },
    {
    "Surname 1": "Nair",
    "Surname 2": "",
    "Name": "Vivek",
    "Email": "vivek.nair05@student.ie.edu",
    "Nationality": "India"
    },
    {
    "Surname 1": "Nisenbaum",
    "Surname 2": "",
    "Name": "Natanel",
    "Email": "natanel.nisenbaum@student.ie.edu",
    "Nationality": "Israel"
    },
    {
    "Surname 1": "Omori",
    "Surname 2": "",
    "Name": "Keisho",
    "Email": "keisho@student.ie.edu",
    "Nationality": "Japan"
    },
    {
    "Surname 1": "Ortega",
    "Surname 2": "Villaseñor",
    "Name": "Regina",
    "Email": "regina.ortega@student.ie.edu",
    "Nationality": "Mexico"
    },
    {
    "Surname 1": "Pacheco",
    "Surname 2": "Bermejo",
    "Name": "Angelica",
    "Email": "angelicapachecober@student.ie.edu",
    "Nationality": "Costa Rica"
    },
    {
    "Surname 1": "Paiewonsky",
    "Surname 2": "Raymores",
    "Name": "Francesca Paola",
    "Email": "fpaiewonsky@student.ie.edu",
    "Nationality": "Dominican Republic"
    },
    {
    "Surname 1": "Pedrosa Riquelme",
    "Surname 2": "",
    "Name": "Santiago",
    "Email": "santiago.pedrosa@student.ie.edu",
    "Nationality": "Spain"
    },
    {
    "Surname 1": "Saca",
    "Surname 2": "",
    "Name": "Mariana",
    "Email": "mariana.saca@student.ie.edu",
    "Nationality": "USA"
    },
    {
    "Surname 1": "Uceda",
    "Surname 2": "Sueldo",
    "Name": "Diego",
    "Email": "diegoucedas@student.ie.edu",
    "Nationality": "Peru"
    },
    {
    "Surname 1": "Valerio",
    "Surname 2": "",
    "Name": "Flavio",
    "Email": "flavio.valerio@student.ie.edu",
    "Nationality": "Peru"
    },
    {
    "Surname 1": "Vastare",
    "Surname 2": "",
    "Name": "Meghana",
    "Email": "mvastare@student.ie.edu",
    "Nationality": "India"
    },
    {
    "Surname 1": "Verona",
    "Surname 2": "Chirinos",
    "Name": "Alvaro",
    "Email": "alvaro.verona@student.ie.edu",
    "Nationality": "Peru"
    },
    {
    "Surname 1": "Vincent",
    "Surname 2": "",
    "Name": "Jim",
    "Email": "jim.vincent@student.ie.edu",
    "Nationality": "France"
    },
    {
    "Surname 1": "Wilhelmi",
    "Surname 2": "Corona",
    "Name": "Luis",
    "Email": "lwilhelmi@student.ie.edu",
    "Nationality": "Germany"
    },
    {
    "Surname 1": "Yared",
    "Surname 2": "",
    "Name": "Rawad",
    "Email": "rawad.yared@student.ie.edu",
    "Nationality": "Lebanon"
    },
    {
    "Surname 1": "Zinca",
    "Surname 2": "",
    "Name": "Luiza",
    "Email": "luiza.zinca@student.ie.edu",
    "Nationality": "Romania"
    }
]

# %% [markdown]
# ## Exercise 1
#
# Create a list with all the students that have a second last name.

# %% [markdown]
# ## Exercise 2
#
# Create a list with all the students whose last name is fully included in their email.

# %% [markdown]
# ## Exercise 3
#
# Add to each student these new keys
# * "Full Name" with the full name of the student
# * "Length of Full Name" with the length of the full name of the student, not including spaces

# %% [markdown]
# ## Exercise 4
#
# Create a dictionary where the keys are the values of "Full Name" and the values are the values of "Length of Full Name".

# %% [markdown]
# ## Exercise 5
#
# Create a list that contains all the last names that are repeated in the dataset.

# %% [markdown]
# ## Exercise 6
#
# Which student has the longest full name?

# %% [markdown]
# ## Exercise 7
#
# For each nationality, create a relationship with all the students for each nationality

# %% [markdown]
# ## Exercise 8
#
# Which nationality has the most students?

# %% [markdown]
# ## Exercise 9
#
# Which nationality has the longest average full name length?

# %% [markdown]
# ## Exercise 10
#
# Which nationality has the most second last names?

# %% [markdown]
# ## Exercise 11
#
# Imagine you are charged with 1 euro per character in your email account.
#
# Create a dictionary where the keys are the emails and the values are the amount of money you would have to pay for that email.

# %% [markdown]
# ## Exercise 12
#
# Create a dictionary where the keys are the nationalities and the values are the average amount of money you would have to pay for the emails of the students

# %% [markdown]
# ## Exercise 13
#
# Create a dictionary where the keys are the nationalities and the values are number of students with that nationality.

# %% [markdown]
# ## Exercise 14
#
# Create a dictionary where the keys are the nationalities and the values are the average length of the full names of the students
