# %% [markdown]
# ## Part 1: Basic Python (Questions 1-5)

# %% [markdown]
# ### 0. Load the student data
#
# Run this cell to load the student data. This is a list of dictionaries where each dictionary represents a student with information about their courses, grades, and study hours.

# %%
students = [
    {
        "name": "Alice",
        "age": 22,
        "major": "Computer Science",
        "gpa": 3.8,
        "courses": ["Python", "Database", "AI"],
        "study_hours": 35,
    },
    {
        "name": "Bob",
        "age": 21,
        "major": "Mathematics",
        "gpa": 3.5,
        "courses": ["Calculus", "Statistics", "Linear Algebra"],
        "study_hours": 28,
    },
    {
        "name": "Charlie",
        "age": 23,
        "major": "Computer Science",
        "gpa": 3.9,
        "courses": ["Python", "Machine Learning", "Data Structures"],
        "study_hours": 40,
    },
    {
        "name": "Diana",
        "age": 20,
        "major": "Physics",
        "gpa": 3.7,
        "courses": ["Quantum Mechanics", "Thermodynamics"],
        "study_hours": 32,
    },
    {
        "name": "Eve",
        "age": 22,
        "major": "Computer Science",
        "gpa": 3.6,
        "courses": ["Python", "Networks", "Security"],
        "study_hours": 30,
    },
    {
        "name": "Frank",
        "age": 24,
        "major": "Mathematics",
        "gpa": 3.4,
        "courses": ["Calculus", "Probability", "Statistics"],
        "study_hours": 25,
    },
    {
        "name": "Grace",
        "age": 21,
        "major": "Physics",
        "gpa": 3.9,
        "courses": ["Classical Mechanics", "Quantum Mechanics"],
        "study_hours": 38,
    },
    {
        "name": "Henry",
        "age": 23,
        "major": "Computer Science",
        "gpa": 3.7,
        "courses": ["Algorithms", "Database", "AI"],
        "study_hours": 33,
    },
    {
        "name": "Ivy",
        "age": 20,
        "major": "Mathematics",
        "gpa": 3.8,
        "courses": ["Linear Algebra", "Statistics", "Probability"],
        "study_hours": 36,
    },
    {
        "name": "Jack",
        "age": 22,
        "major": "Physics",
        "gpa": 3.5,
        "courses": ["Thermodynamics", "Electromagnetism"],
        "study_hours": 29,
    },
]

print(f"Total students: {len(students)}")
students[0]
# Out:
# Total students: 10
# {'name': 'Alice',
#  'age': 22,
#  'major': 'Computer Science',
#  'gpa': 3.8,
#  'courses': ['Python', 'Database', 'AI'],
#  'study_hours': 35}

# %% [markdown]
# ### Question 1: How many students are majoring in Computer Science? (1 point)
#
# Print or return the solution you find using code.
#
# **Solution: 4**

# %% [markdown]
# ### Question 2: Add a new key-value pair to each student dictionary (1 point)
#
# Add a new key called `num_courses` that contains the number of courses each student is taking.
#
# Test it on the first student (Alice), the answer should be **3**.
#
# Print or return the solution you find using code.

# %% [markdown]
# ### Question 3: Build a dictionary with major statistics (1 point)
#
# Create a dictionary with the following structure:
# ```python
# {major: average_gpa_of_students_in_that_major}
# ```
#
# The keys should be the major names, and the values should be the average GPA of students in that major.
#
# Test it on `"Computer Science"`, the answer should be approximately **3.75**.
#
# Print or return the solution you find using code.

# %% [markdown]
# ### Question 4: Create two functions (1 point)
#
# **Part A (0.5 points):** Create a function called `high_achievers` that:
# - Takes the students list and a GPA threshold
# - Returns the number of students with a GPA greater than or equal to the threshold
#
# Test: `high_achievers(students, 3.7)` should return **6**
#
# **Part B (0.5 points):** Create a function called `takes_course` that:
# - Takes the students list and a course name
# - Returns a list of student names who are taking that course
#
# Test: `takes_course(students, "Python")` should return **['Alice', 'Charlie', 'Eve']**
#
# Print or return the solutions you find using code.

# %% [markdown]
# ### Question 5: List comprehension and filtering (1 point)
#
# Using a list comprehension, create a list of tuples where each tuple contains:
# - Student name
# - Their study hours per course (total study_hours divided by num_courses)
#
# **Only include students who study more than 10 hours per course.**
#
# **Solution:**
# ```
# [('Alice', 11.666666666666666),
#  ('Charlie', 13.333333333333334),
#  ('Diana', 16.0),
#  ('Grace', 19.0),
#  ('Henry', 11.0),
#  ('Ivy', 12.0),
#  ('Jack', 14.5)]
# ```
#
# Print or return the solution you find using code.

# %% [markdown]
# ## Part 2: Pandas (Questions 6-10)
#
# Use pandas to answer the following questions based on the student data loaded in Question 0.

# %% [markdown]
# ### Question 6: Load and clean the dataset (1 point)
#
# Convert the list of dictionaries from Exercise 0 into a Pandas DataFrame named `df`.
#
# Then, calculate the average GPA for each major and display the result as a series with the major in the index.
#
# **Solution:**
#
# ```
# major
# Computer Science    3.750000
# Mathematics         3.566667
# Physics             3.700000
# Name: gpa, dtype: float64
# ```

# %% [markdown]
# ### Question 7: Filtering and counting (1 point)
#
# How many entries are there where:
# - `major` is `'Mathematics'`
# - `num_courses` is 2
#
# **Solution: 3**
#
# Print or return the solution you find using code.

# %% [markdown]
# ### Question 8: Adding data (1 point)
#
# Add a new column called `gpa_per_study_hour` that contains the GPA divided by the total study hours for each student.
#
# Then, find the student with the highest `gpa_per_study_hour` and return their name.
#
# **Solution: 'Frank'**

# %% [markdown]
# ### Question 9: Comparing aggregated values (1 point)
#
# According to `gpa_per_study_hour`, which major has the highest average value? Use `idxmax()` to find the major name.
#
# **Solution: 'Mathematics'**

# %% [markdown]
# ### Question 10: Advanced filtering and sorting (1 point)
#
# For each major, how many students have a `gpa_per_study_hour` above the overall median `gpa_per_study_hour`?
#
# Return a series with majors as the index and counts as values.
#
# **Solution:**
#
# ```
# major
# Computer Science    1
# Mathematics         2
# Physics             2
# dtype: int64
# ```
