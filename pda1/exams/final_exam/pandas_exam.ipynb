# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Question 1
# Load the dataset `../data/social_media_addiction.csv` into a DataFrame named `df`. Display the data types of all columns.

# %% [markdown]
# ## Question 2
#
# Convert all columns to lowercase and with no spaces (replace spaces with underscores). Display the first 5 rows of the modified DataFrame.

# %% [markdown]
# ## Question 3
# Rename the column `sleep_hours_per_night` to `sleep_hours`. Display the first 5 rows to verify the change.

# %% [markdown]
# ## Question 4
# How many students are there who live in the 'Spain' AND are currently 'Undergraduate' students?
#
# Solution: 22

# %% [markdown]
# ## Question 5
#
# Calculate and display the standard deviation of age for each academic level.

# %% [markdown]
# ## Question 6
# Create a new column named `no_conflicts` that contains `True` if `conflicts_over_social_media` is 0 and `False` otherwise. Display the first 5 rows of the DataFrame with this new column.

# %% [markdown]
# ## Question 7
# Display the top 5 students with the highest `mental_health_score`. If there is a tie in the score, sort them by `age` in ascending order (youngest first).

# %% [markdown]
# ## Question 8
#
# What's the 3rd country with the highest amount of conflicts over social media?
#
# Return its name as a string.
#
# Solution: `'Canada'`

# %% [markdown]
# ## Question 9
#
# What's the difference in the average `mental_health_score` between students in a relationship and those who are single?
#
# Solution: 0.0996

# %% [markdown]
# ## Question 10
#
# Create a new column with the standardized version of `sleep_hours`, called `sleep_hours_scaled`, you can use the Z-Score for this: substract from each value the mean of the variable and divide it by its standard deviation.
#
# $$ x_{i, scaled} = \frac{x_{i} - \mu }{\sigma} $$
#
# What's the mean of the new column?
#
# Solution: 0

# %% [markdown]
# ## Question 11
# Given the new column from Q10, first create a df containing all the students whose `sleep_hours_scaled` is greater than 2 OR smaller than -2.
#
# Which country has the highest number of students in this new df? Return the country name as a string.
#
# Solution: `'USA'`

# %% [markdown]
# ## Question 12
#
# Which combination of `gender` and `academic_level` has the lowest average `mental_health_score`?
#
# Return the combination as a tuple: (`gender`, `academic_level`).
#
# Solution: `('Female', 'High School')` or `('High School', 'Female')`

# %% [markdown]
# ## Question 13
# Create a new numeric column `risk_factor` which is calculated as follows:
#
# $$
# \text{risk\_factor} = \frac{\text{addicted\_score} \cdot \text{conflicts\_over\_social\_media}}{\text{sleep\_hours} \cdot \text{mental\_health\_score}}
# $$

# %% [markdown]
# ## Question 14
#
# Which academic level has a higher presence of at-risk students? (consider at-risk students those whose risk factor is above the mean).
#
# And how many at-risk students are there in that academic level?
#
# Solution: `'Undergraduate', 147`

# %% [markdown]
# ## Question 15 (Open ended question)
#
# Which is the worst social media platform?
