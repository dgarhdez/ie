# %%
# Google Colab Setup - Run this cell first!
# This downloads the data files needed for this exam

import os

# Only run setup if we're in Colab
if 'google.colab' in str(get_ipython()):
    # !git clone --depth 1 -q https://github.com/dgarhdez/ie.git /content/ie 2>/dev/null || true
    os.chdir('/content/ie/pda1_test/exams')
    print("Setup complete! Data files are ready.")

# %% [markdown]
# # Individual Assignment: Movies!
#
# There are 12 questions in this assignment. Some questions unlock others. If you can't answer a question, you can skip it and come back to it later, and if the question is locked, I'll provide a data sample for you to use, **at a cost of 0.5 points.**
#
# The movies dataset is available in the file `movies.json`. This data contains information about movies. It's a list of dictionaries, where each dictionary represents a movie. The keys in the dictionary are:
#
# * `title`: the title of the movie
# * `year`: the year the movie was released
# * `genre`: the main genre of the movie
# * `director`: the name of the director
# * `rating`: IMDb rating (1-10)
# * `votes`: number of votes the movie received
# * `runtime`: duration in minutes
# * `country`: the country where the movie was produced
# * `language`: the main language of the movie
# * `budget`: production budget in USD (can be None)
# * `revenue`: box office revenue in USD (can be None)
#
#
# ### Rules:
# * For each question, print the answer in the cell below the question. You can use `print()` or just type the variable name.
# * You can use any resources you like --including the internet, your notes, and the past notebooks-- except ChatGPT/Copilot/other AI writing tools. Using AI-based tools or asking other people for help will result in a 0 for the assignment, an immediate Fail in the course, and a report to the Dean of Students.
# * You have 80 minutes to complete the assignment.
# * You can submit the assignment as many times as you like, only the last submission will be graded.
# * You can't work with other people on the assignment.

# %% [markdown]
# ### 0. Load the data as a Python object and print the first item
#
# If `"utf-8"` encoding gives an error, try `"latin-1"` instead.

# %%
import json

with open("movies.json", encoding="utf-8") as f:
    movies = json.load(f)

# %%
movies[0]

# %% [markdown]
# ### 1. How many movies are included in the dataset? (1 point)
#
# Print or return the solution you find using code.
#
# Solution: 1000

# %% [markdown]
# ### 2. Add a new key and value pair in each item in the list (1 point)
#
# The new key should be called `title_length` and it should indicate the number of characters in the `title` (including spaces).
#
# For example, the following title should have a *title_length* value of 10:
# * "The Matrix"
#
# Test it on the first item in the list.
#
# Print or return the solution you find using code.

# %% [markdown]
# ### 3. How many different countries have movies in the dataset? (1 point)
#
# PSA: There may be `None` values in the `country` key.
#
# Print or return the solution you find using code.

# %% [markdown]
# ### 4. Build a new dictionary with the following structure: (1 point)
#
# `{genre: number of movies in that genre}`
#
# The keys should be the genre names, and the values should be the number of movies in that genre.
#
# Test it on `"Drama"` to verify your answer.
#
# Print or return the solution you find using code.

# %% [markdown]
# ### 5. Build a dictionary with the following structure (1 point)
#
# `{genre: average rating of movies in that genre}`
#
# The keys should be the genre names, and the values should be the average rating of movies in that genre.
#
# Test it on `"Comedy"` to verify your answer.
#
# Print or return the solution you find using code.

# %% [markdown]
# ### 6. What's the director that has the highest average movie rating? (1 point)
#
# Follow a similar approach to question 5.
#
# Print or return the solution you find using code.

# %% [markdown]
# ### 7. Create a new key and value pair in each item in the list (1 point):
#
# The key should be called `decade` and it should indicate which decade the movie was released in.
#
# For example:
# * A movie from 1995 should have `decade` = `"1990s"`
# * A movie from 2003 should have `decade` = `"2000s"`
# * A movie from 2018 should have `decade` = `"2010s"`
#
# **Hint**: Use integer division (`//`) to help calculate the decade.
#
# Test it on the first item in the list.
#
# Print or return the solution you find using code.

# %% [markdown]
# ### 8. What's the percentage of movies that have a budget recorded? (1 point)
#
# Remember that some movies have `None` as their budget value.
#
# Print or return the solution you find using code.

# %% [markdown]
# ### 9. Create two functions (1 point)
#
# * Create a function called `long_movies` that receives the movies list and a minimum runtime (in minutes), and returns how many movies have a runtime greater than or equal to that value. (0.5 points)
#
# * Create another function called `is_blockbuster` that receives a movie dictionary and returns `True` if the movie has revenue greater than 100,000,000, and `False` otherwise (or if revenue is `None`). (0.5 points)
#
# Test your functions with these examples:
#
# * `long_movies(movies, 180)` should return the count of movies that are 3+ hours long
# * `is_blockbuster(movies[0])` should return `True` or `False` based on the first movie's revenue

# %% [markdown]
# ### 10. Movie Analytics (1 point)
#
# * Which is the most common genre in the dataset?
# * Which is the longest movie in the dataset (by runtime)? Print its title.
# * Which is the highest-rated movie in the dataset? Print its title and rating.
#
# Print or return the solutions you find using code.

# %% [markdown]
# ### 11. Using lambda functions and the `filter` function (1 point)
#
# Create a list of all movies that have a rating of 8.0 or higher.
#
# Print the number of highly-rated movies and the title of the first one in the filtered list.
#
# Print or return the solution you find using code.

# %% [markdown]
# ### 12. Is there a relationship between runtime and rating? (1 point)
#
# Calculate the average rating for:
# * Short movies (runtime < 100 minutes)
# * Medium movies (runtime between 100 and 150 minutes)
# * Long movies (runtime > 150 minutes)
#
# Based on your results, briefly explain whether longer movies tend to have higher or lower ratings.
#
# Print or return the solutions you find using code, and write your brief explanation as a comment or print statement.
